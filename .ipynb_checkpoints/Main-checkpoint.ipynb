# %%
import gather
import pickle

testuserlist,userlist=gather.gatherUsersFromManyRatedGames(2,5)
print(len(testuserlist),len(userlist))

with open('usereval.list', 'wb') as f:
    pickle.dump(testuserlist, f)

with open('userlearn.list', 'wb') as f:
    pickle.dump(userlist, f)

# %%
import pickle
import numpy as np

with open('userlearn.list', 'rb') as f:
    userlist=pickle.load(f)

R=np.zeros( (40000, 10000), dtype="float16")
I=np.zeros_like(R, dtype="bool")
It=np.zeros_like(R, dtype="bool")
    
with open('iterid.val', 'wb') as f:
    pickle.dump(0, f)
    
with open('rating.nda', 'wb') as f:
    pickle.dump(R, f)

with open('rated.nda', 'wb') as f:
    pickle.dump(I, f)

with open('ratedTest.nda', 'wb') as f:
    pickle.dump(It, f)

with open('games.list', 'wb') as f:
    pickle.dump([],f)

# %%
import gather
import pickle
import time

batch=1000

with open('userlearn.list', 'rb') as f:
    userlist=pickle.load(f)

with open('iterid.val','rb') as f:
    iterid=pickle.load(f)
    
with open('rating.nda', 'rb') as f:
    R=pickle.load(f)

with open('rated.nda', 'rb') as f:
    I=pickle.load(f)

with open('ratedTest.nda', 'rb') as f:
    It=pickle.load(f)
    
with open('games.list', 'rb') as f:
    gamelist=pickle.load(f)
    
l=10000

while iterid<l:
    print("----------------")
    print("\t",iterid)
    gather.gatherRatingsFromUsers(userlist[:6000],iterid,batch,R,I,It,gamelist)
    
    print("")
    print("#",len(gamelist))
    time.sleep(5)
    iterid+=batch

    with open('iterid.val', 'wb') as f:
        pickle.dump(iterid, f)

    with open('rating.nda', 'wb') as f:
        pickle.dump(R, f)
    
    with open('rated.nda', 'wb') as f:
        pickle.dump(I, f)
        
    with open('ratedTest.nda', 'wb') as f:
        pickle.dump(It, f)
    
    with open('games.list', 'wb') as f:
        pickle.dump(gamelist,f)

# %%
import pickle
import gather

with open('userlearn.list', 'rb') as f:
    userlist=pickle.load(f)

with open('games.list', 'rb') as f:
    gamelist=pickle.load(f)

with open('rating.nda', 'rb') as f:
    R=pickle.load(f)

with open('rated.nda', 'rb') as f:
    I=pickle.load(f)

with open('ratedTest.nda', 'rb') as f:
    It=pickle.load(f)

with open('cutData.ndas','wb') as f:
    pickle.dump( gather.cut(gamelist,userlist[:6000],R,I,It,gamedeg=32,userdeg=32), f)

# %%
import pickle
import numpy as np

with open('cutData.ndas','rb') as f:
    gamelist,userlist,R,I,It = pickle.load(f)
    
a=np.sum(I,axis=0)
b=np.sum(I,axis=1)

print(I.shape)
print( np.mean(a), np.max(a) )
print( np.mean(b), np.max(b) )

# %%
import pickle
import numpy as np
import baseline


with open('cutData.ndas','rb') as f:
    gamelist,userlist,R,I,It = pickle.load(f)
    
print("loaded")
    
bm,bg,bu= baseline.baseline(R,I,It)
print(bm,np.mean(bg),np.std(bg),np.mean(bu),np.std(bu))    
    
with open('baseline.ndas', 'wb') as f:
    pickle.dump((bm,bg,bu),f)

# %%
import pickle
import gather

with open('cutData.ndas','rb') as f:
    gamelist,_,_,_,_ = pickle.load(f)
    _=None

with open('gameinfo.lists','wb') as f:
    pickle.dump(gather.gatherInformationOfGames(gamelist),f)

# %%
import pickle
import baseline
import numpy as np

with open('cutData.ndas','rb') as f:
    gamelist,userlist,R,I,It = pickle.load(f)

with open('baseline.ndas', 'rb') as f:
    bm,bg,bu = pickle.load(f)
    
with open('gameinfo.lists','rb') as f:
    namelist, minplist, maxplist, weightlist, catmeclist = pickle.load(f)

cw, bw = baseline.weightbase(R,I,It,bm,bg,bu,weightlist)

print(np.mean(cw),np.std(cw),np.mean(bw),np.std(bw))

with open('weightbase.ndas', 'wb') as f:
    pickle.dump((cw,bw),f)

# %%
import pickle
import baseline
import numpy as np

with open('cutData.ndas','rb') as f:
    gamelist,userlist,R,I,It = pickle.load(f)

with open('baseline.ndas', 'rb') as f:
    bm,bg,bu = pickle.load(f)
    
with open('gameinfo.lists','rb') as f:
    namelist, minplist, maxplist, weightlist, catmeclist = pickle.load(f)

cw, bw = baseline.weightbase(R,I,It,bm,bg,bu,weightlist)

print(np.mean(cw),np.std(cw),np.mean(bw),np.std(bw))

with open('weightbase.ndas', 'wb') as f:
    pickle.dump((cw,bw),f)

# %%
import pickle
import MF
import numpy as np

with open('cutData.ndas','rb') as f:
    gamelist,userlist,R,I,It = pickle.load(f)

with open('baseline.ndas', 'rb') as f:
    bm,bg,bu = pickle.load(f)

Fg, Fu = MF.WALS(R,I,It,bm,bg,bu,8)

print(np.mean(Fg,axis=0),np.std(Fg,axis=0),np.mean(Fu,axis=1),np.std(Fu,axis=1))

with open('MF.ndas', 'wb') as f:
    pickle.dump((Fg,Fu),f)

# %%
import pickle
import numpy as np
import blender

with open('cutData.ndas','rb') as f:
    gamelist,userlist,R,I,It = pickle.load(f)

with open('baseline.ndas', 'rb') as f:
    bm,bg,bu = pickle.load(f)

with open('gameinfo.lists','rb') as f:
    namelist, minplist, maxplist, weightlist, catmeclist = pickle.load(f)
    
with open('weightbase.ndas', 'rb') as f:
    cw,bw=pickle.load(f)
    
with open('MF.ndas', 'rb') as f:
    Fg,Fu = pickle.load(f)

_TL = np.sum(It)
Iu=np.sum(I,axis=0,keepdims=True)

Rtrivial = np.zeros_like(R) + np.sum(I*R,axis=1,keepdims=True)/np.sum(I,axis=1,keepdims=True)
R0 = bm+np.expand_dims(bg,1)+bu
w = np.expand_dims( np.array(weightlist, dtype="float32"), 1)
wd = np.abs(w-cw)
wsum = np.sum(I*wd, axis=0, keepdims=True)
R1 = R0+bw*(wsum/Iu-wd)
R2= R0+Fg@Fu

ratios=blender.blend(R,I,It,np.stack((Rtrivial,R0,R1,R2)))
print(ratios)

with open('blend.nda','wb') as f:
    pickle.dump(ratios,f)
# Out:
# 4
# 1.7953923171426323 1.4911905705871968 1.4528510735169957 1.4266288995126797
# WARNING:tensorflow:From C:\Users\user\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# ...
# ...
# ...
# WARNING:tensorflow:From C:\Users\user\Anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# ...
# initiated
# 1.7527833 1.810602
# 1.3302404 1.4387503
# 1.3990407 1.5579929
# 1.5584373 1.7382003
# 1.4873844 1.6595229
# 1.3469346 1.4968255
# 1.2999271 1.423343
# 1.3618053 1.4635782
# 1.424326 1.5158951
# 1.4100436 1.5039439
# 1.345778 1.4515777
# 1.2989328 1.4218096
# 1.305509 1.4456823
# 1.3433591 1.4962066
# 1.3637162 1.5214597
# 1.3458899 1.5004015
# 1.3107632 1.4559008
# 1.291446 1.4243289
# 1.3003929 1.4218178
# 1.3207712 1.4347434
# 1.3275064 1.4398347
# 1.3137789 1.4302539
# 1.2942401 1.4190958
# 1.286795 1.4217399
# 1.2945763 1.4384677
# 1.3049573 1.4542624
# 1.3048353 1.4548469
# 1.2942314 1.4405812
# 1.2840285 1.423941
# 1.2829893 1.415961
# 1.2889405 1.4167286
# 1.2926769 1.4186063
# 1.288944 1.4167705
# 1.2814955 1.4142321
# 1.2775645 1.4166213
# 1.2793992 1.4242454
# 1.2825096 1.4309567
# 1.2817352 1.430762
# 1.27721 1.4240227
# 1.2733678 1.4163071
# 1.273163 1.4121679
# 1.2748575 1.4113702
# 1.2747828 1.4111497
# 1.2719992 1.4106063
# 1.2689881 1.4114413
# 1.2681171 1.4147437
# 1.268773 1.4185928
# 1.2685798 1.419746
# 1.2666236 1.4171575
# 1.2643623 1.4128855
# 1.2634084 1.4096055
# 1.2634557 1.4081092
# 1.2629745 1.4075906
# 1.261384 1.4075732
# 1.2596554 1.4085174
# 1.2587868 1.4105294
# 1.2584786 1.412404
# 1.2577417 1.4125863
# 1.2563368 1.410816
# 1.2549759 1.4082972
# 1.2541971 1.4063396
# 1.2536541 1.4053173
# 1.2527392 1.4050028
# 1.2514719 1.4053259
# [0.14866543 0.1879481  0.2495174  0.41566435]
